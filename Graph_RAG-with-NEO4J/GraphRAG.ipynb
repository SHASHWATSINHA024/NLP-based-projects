# %%
# extracted the output , and  made it json file

# %%
results='''[
    {
        "node_1": "James Bond series",
        "node_2": "James Bond",
        "edge": "focuses_on"
    },
    {
        "node_1": "James Bond",
        "node_2": "British Secret Service agent",
        "edge": "is_a"
    },
    {
        "node_1": "James Bond",
        "node_2": "Ian Fleming",
        "edge": "created_by"
    },
    {
        "node_1": "Ian Fleming",
        "node_2": "novels",
        "edge": "featured_in"
    },
    {
        "node_1": "Ian Fleming",
        "node_2": "short-story collections",
        "edge": "featured_in"
    },
    {
        "node_1": "Fleming",
        "node_2": "Bond novels",
        "edge": "wrote"
    },
    {
        "node_1": "Fleming",
        "node_2": "Bond novelisations",
        "edge": "wrote"
    },
    {
        "node_1": "Fleming",
        "node_2": "1964",
        "edge": "died_in"
    },
    {
        "node_1": "eight other authors",
        "node_2": "Bond novels",
        "edge": "wrote"
    },
    {
        "node_1": "eight other authors",
        "node_2": "Bond novelisations",
        "edge": "wrote"
    },
    {
        "node_1": "Kingsley Amis",
        "node_2": "Bond novels",
        "edge": "wrote"
    },
    {
        "node_1": "Kingsley Amis",
        "node_2": "Bond novelisations",
        "edge": "wrote"
    },
    {
        "node_1": "Christopher Wood",
        "node_2": "Bond novels",
        "edge": "wrote"
    },
    {
        "node_1": "Christopher Wood",
        "node_2": "Bond novelisations",
        "edge": "wrote"
    },
    {
        "node_1": "John Gardner",
        "node_2": "Bond novels",
        "edge": "wrote"
    },
    {
        "node_1": "John Gardner",
        "node_2": "Bond novelisations",
        "edge": "wrote"
    },
    {
        "node_1": "Raymond Benson",
        "node_2": "Bond novels",
        "edge": "wrote"
    },
    {
        "node_1": "Raymond Benson",
        "node_2": "Bond novelisations",
        "edge": "wrote"
    },
    {
        "node_1": "Sebastian Faulks",
        "node_2": "Bond novels",
        "edge": "wrote"
    },
    {
        "node_1": "Sebastian Faulks",
        "node_2": "Bond novelisations",
        "edge": "wrote"
    },
    {
        "node_1": "Jeffery Deaver",
        "node_2": "Bond novels",
        "edge": "wrote"
    },
    {
        "node_1": "Jeffery Deaver",
        "node_2": "Bond novelisations",
        "edge": "wrote"
    },
    {
        "node_1": "William Boyd",
        "node_2": "Bond novels",
        "edge": "wrote"
    },
    {
        "node_1": "William Boyd",
        "node_2": "Bond novelisations",
        "edge": "wrote"
    },
    {
        "node_1": "Anthony Horowitz",
        "node_2": "Bond novels",
        "edge": "wrote"
    },
    {
        "node_1": "Anthony Horowitz",
        "node_2": "Bond novelisations",
        "edge": "wrote"
    },
    {
        "node_1": "The latest novel",
        "node_2": "With a Mind to Kill",
        "edge": "is"
    },
    {
        "node_1": "With a Mind to Kill",
        "node_2": "Anthony Horowitz",
        "edge": "by"
    },
    {
        "node_1": "With a Mind to Kill",
        "node_2": "May 2022",
        "edge": "published_in"
    },
    {
        "node_1": "Charlie Higson",
        "node_2": "young James Bond series",
        "edge": "wrote"
    },
    {
        "node_1": "Kate Westbrook",
        "node_2": "Moneypenny diaries novels",
        "edge": "wrote"
    },
    {
        "node_1": "James Bond",
        "node_2": "007",
        "edge": "also_known_as"
    },
    {
        "node_1": "James Bond",
        "node_2": "young James Bond series",
        "edge": "featured_in"
    },
    {
        "node_1": "Moneypenny",
        "node_2": "Moneypenny diaries novels",
        "edge": "featured_in"
    },
    {
        "node_1": "James Bond",
        "node_2": "television",
        "edge": "adapted_for"
    },
    {
        "node_1": "James Bond",
        "node_2": "radio",
        "edge": "adapted_for"
    },
    {
        "node_1": "James Bond",
        "node_2": "comic strip",
        "edge": "adapted_for"
    },
    {
        "node_1": "James Bond",
        "node_2": "video games",
        "edge": "adapted_for"
    },
    {
        "node_1": "James Bond",
        "node_2": "film",
        "edge": "adapted_for"
    },
    {
        "node_1": "films",
        "node_2": "film series",
        "edge": "belong_to"
    },
    {
        "node_1": "films",
        "node_2": "box office",
        "edge": "grossed_over"
    },
    {
        "node_1": "films",
        "node_2": "US$7.04 billion",
        "edge": "total_gross"
    },
    {
        "node_1": "film series",
        "node_2": "1962",
        "edge": "started_in"
    },
    {
        "node_1": "film series",
        "node_2": "fifth-highest-grossing",
        "edge": "ranked_as"
    },
    {
        "node_1": "film series",
        "node_2": "Dr. No",
        "edge": "started_with"
    },
    {
        "node_1": "Sean Connery",
        "node_2": "Bond",
        "edge": "portrays"
    },
    {
        "node_1": "Bond",
        "node_2": "Eon Productions",
        "edge": "series"
    },
    {
        "node_1": "Eon Productions",
        "node_2": "films",
        "edge": "produced"
    },
    {
        "node_1": "films",
        "node_2": "2021",
        "edge": "released_until"
    },
    {
        "node_1": "Bond film",
        "node_2": "No Time to Die (2021)",
        "edge": "is"
    },
    {
        "node_1": "No Time to Die (2021)",
        "node_2": "Daniel Craig",
        "edge": "stars"
    },
    {
        "node_1": "Daniel Craig",
        "node_2": "Bond",
        "edge": "portrays"
    },
    {
        "node_1": "Bond",
        "node_2": "Daniel Craig",
        "edge": "played_by"
    },
    {
        "node_1": "Daniel Craig",
        "node_2": "fifth",
        "edge": "has"
    },
    {
        "node_1": "Bond",
        "node_2": "Eon series",
        "edge": "is_part_of"
    },
    {
        "node_1": "Daniel Craig",
        "node_2": "sixth",
        "edge": "is"
    },
    {
        "node_1": "Bond",
        "node_2": "actor",
        "edge": "is_played_by"
    },
    {
        "node_1": "Bond film productions",
        "node_2": "Casino Royale (1967)",
        "edge": "includes"
    },
    {
        "node_1": "Casino Royale (1967)",
        "node_2": "David Niven",
        "edge": "starring"
    },
    {
        "node_1": "Bond film productions",
        "node_2": "Never Say Never Again (1983)",
        "edge": "includes"
    },
    {
        "node_1": "Bond",
        "node_2": "Scorpius",
        "edge": "published in"
    },
    {
        "node_1": "Bond",
        "node_2": "Win, Lose or Die",
        "edge": "published in"
    },
    {
        "node_1": "Bond",
        "node_2": "Licence to Kill",
        "edge": "novelisation of"
    },
    {
        "node_1": "Bond",
        "node_2": "Brokenclaw",
        "edge": "published in"
    },
    {
        "node_1": "Bond",
        "node_2": "The Man from Barbarossa",
        "edge": "published in"
    },
    {
        "node_1": "Bond",
        "node_2": "Death Is Forever",
        "edge": "published in"
    },
    {
        "node_1": "Bond",
        "node_2": "Never Send Flowers",
        "edge": "published in"
    },
    {
        "node_1": "Bond",
        "node_2": "SeaFire",
        "edge": "published in"
    },
    {
        "node_1": "Bond",
        "node_2": "GoldenEye",
        "edge": "novelisation of"
    },
    {
        "node_1": "Bond",
        "node_2": "Cold",
        "edge": "published in"
    },
    {
        "node_1": "final_final_ans(",
        "node_2": "Bond novels",
        "edge": "author of"
    },
    {
        "node_1": "Benson",
        "node_2": "The James Bond Bedside Companion",
        "edge": "authored"
    },
    {
        "node_1": "Benson",
        "node_2": "six Bond novels",
        "edge": "wrote"
    },
    {
        "node_1": "Benson",
        "node_2": "three novelisations",
        "edge": "wrote"
    },
    {
        "node_1": "Benson",
        "node_2": "three short stories",
        "edge": "wrote"
    },
    {
        "node_1": "Benson",
        "node_2": "Blast From the Past",
        "edge": "authored"
    },
    {
        "node_1": "Benson",
        "node_2": "Zero Minus Ten",
        "edge": "authored"
    },
    {
        "node_1": "Benson",
        "node_2": "Tomorrow Never Dies",
        "edge": "novelised"
    },
    {
        "node_1": "Benson",
        "node_2": "The Facts of Death",
        "edge": "authored"
    },
    {
        "node_1": "Benson",
        "node_2": "Midsummer Night's Doom",
        "edge": "authored"
    },
    {
        "node_1": "Benson",
        "node_2": "Live at Five",
        "edge": "authored"
    },
    {
        "node_1": "Benson",
        "node_2": "The World Is Not Enough",
        "edge": "novelised"
    },
    {
        "node_1": "Benson",
        "node_2": "High Time to Kill",
        "edge": "authored"
    },
    {
        "node_1": "Benson",
        "node_2": "DoubleShot",
        "edge": "authored"
    },
    {
        "node_1": "Benson",
        "node_2": "Never Dream of Dying",
        "edge": "authored"
    },
    {
        "node_1": "Benson",
        "node_2": "The Man with the Red Tattoo",
        "edge": "authored"
    },
    {
        "node_1": "Benson",
        "node_2": "Die Another Day",
        "edge": "novelised"
    },
    {
        "node_1": "Sebastian Faulks",
        "node_2": "Devil May Care",
        "edge": "authored"
    },
    {
        "node_1": "American writer Jeffery Deaver",
        "node_2": "Carte Blanche",
        "edge": "authored"
    },
    {
        "node_1": "William Boyd",
        "node_2": "Solo",
        "edge": "authored"
    },
    {
        "node_1": "Anthony Horowitz",
        "node_2": "Bond continuation novel",
        "edge": "to write"
    },
    {
        "node_1": "Bond continuation novel",
        "node_2": "Goldfinger",
        "edge": "follows events of"
    },
    {
        "node_1": "Trigger Mortis",
        "node_2": "Bond novel",
        "edge": "is_a"
    },
    {
        "node_1": "Trigger Mortis",
        "node_2": "Horowitz",
        "edge": "written_by"
    },
    {
        "node_1": "Trigger Mortis",
        "node_2": "8 September 2015",
        "edge": "released_on"
    },
    {
        "node_1": "Forever and a Day",
        "node_2": "Bond novel",
        "edge": "is_a"
    },
    {
        "node_1": "Forever and a Day",
        "node_2": "Horowitz",
        "edge": "written_by"
    },
    {
        "node_1": "Forever and a Day",
        "node_2": "Bond",
        "edge": "about"
    },
    {
        "node_1": "Forever and a Day",
        "node_2": "origin story",
        "edge": "tells"
    },
    {
        "node_1": "Bond",
        "node_2": "00 agent",
        "edge": "is_a"
    },
    {
        "node_1": "Forever and a Day",
        "node_2": "Casino Royale",
        "edge": "precedes"
    },
    {
        "node_1": "novel",
        "node_2": "unpublished material from Fleming",
        "edge": "based_on"
    },
    {
        "node_1": "novel",
        "node_2": "release",
        "edge": "announced_on"
    },
    {
        "node_1": "Horowitz's third Bond novel",
        "node_2": "publication",
        "edge": "occurred_on"
    },
    {
        "node_1": "Charlie Higson's first adult Bond novel",
        "node_2": "publication",
        "edge": "occurred_on"
    },
    {
        "node_1": "Charlie Higson's first adult Bond novel",
        "node_2": "Coronation of King Charles III",
        "edge": "celebrates"
    },
    {
        "node_1": "Charlie Higson's first adult Bond novel",
        "node_2": "National Literacy Trust",
        "edge": "supports"
    },
    {
        "node_1": "Devil May Care",
        "node_2": "release",
        "edge": "occurred_in"
    },
    {
        "node_1": "Carte Blanche",
        "node_2": "release",
        "edge": "occurred_in"
    },
    {
        "node_1": "Solo",
        "node_2": "release",
        "edge": "occurred_in"
    },
    {
        "node_1": "Trigger Mortis",
        "node_2": "release",
        "edge": "occurred_in"
    },
    {
        "node_1": "Forever and a Day",
        "node_2": "release",
        "edge": "occurred_in"
    },
    {
        "node_1": "With a Mind to Kill",
        "node_2": "release",
        "edge": "occurred_in"
    },
    {
        "node_1": "On His Majesty's Secret Service",
        "node_2": "publication",
        "edge": "occurred_on"
    },
    {
        "node_1": "Young Bond series",
        "node_2": "Charlie Higson",
        "edge": "started_by"
    },
    {
        "node_1": "Young Bond series",
        "node_2": "novels",
        "edge": "includes"
    },
    {
        "node_1": "SilverFin",
        "node_2": "graphic novel",
        "edge": "adapted_into"
    },
    {
        "node_1": "Young Bond series",
        "node_2": "Stephen Cole",
        "edge": "continued_by"
    },
    {
        "node_1": "The Moneypenny Diaries",
        "node_2": "novels",
        "edge": "comprises"
    },
    {
        "node_1": "The Moneypenny Diaries",
        "node_2": "Miss Moneypenny",
        "edge": "features"
    },
    {
        "node_1": "Samantha Weinberg",
        "node_2": "author",
        "edge": "is_a"
    },
    {
        "node_1": "Samantha Weinberg",
        "node_2": "Kate Westbrook",
        "edge": "pseudonym"
    }

,
    {
        "node_1": "Cubby Broccoli",
        "node_2": "Dr. No",
        "edge": "released"
    },
    {
        "node_1": "Dr. No",
        "node_2": "Ian Fleming",
        "edge": "novel_by"
    },
    {
        "node_1": "Dr. No",
        "node_2": "cinema adaptation",
        "edge": "is_a"
    },
    {
        "node_1": "Dr. No",
        "node_2": "Sean Connery",
        "edge": "starring"
    },
    {
        "node_1": "Sean Connery",
        "node_2": "James Bond",
        "node_1": "film series",
        "node_2": "2006",
        "edge": "started_in"
    },
    {
        "node_1": "film series",
        "node_2": "$7 billion",
        "edge": "grossed"
    },
    {
        "node_1": "film series",
        "node_2": "fifth-highest-grossing",
        "edge": "is"
    }]'''
type(results)
# Out:
# str

# %%
import json
import pandas as pd
data = json.loads(results)

# Convert to DataFrame
df = pd.DataFrame(data)


print("DataFrame:")
print(df)
# Out:
# DataFrame:
#                    node_1                        node_2         edge
# 0       James Bond series                    James Bond   focuses_on
# 1              James Bond  British Secret Service agent         is_a
# 2              James Bond                   Ian Fleming   created_by
# 3             Ian Fleming                        novels  featured_in
# 4             Ian Fleming       short-story collections  featured_in
# ..                    ...                           ...          ...
# 159  Casino Royale (2006)                   film series     rebooted
# 160          Daniel Craig                   film series  appeared_in
# 161           film series                          2006   started_in
# 162           film series                    $7 billion      grossed
# 163           film series        fifth-highest-grossing           is
#
# [164 rows x 3 columns]

# %%
# !pip install neo4j
# Out:
# Requirement already satisfied: neo4j in c:\users\shashwat's pc\appdata\local\programs\python\python310\lib\site-packages (5.21.0)
# Requirement already satisfied: pytz in c:\users\shashwat's pc\appdata\local\programs\python\python310\lib\site-packages (from neo4j) (2024.1)
# [notice] A new release of pip available: 22.2.1 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# made a neo4j graph based on my entities and relation json

# %%
import json
from neo4j import GraphDatabase


driver = GraphDatabase.driver(uri, auth=(user, password))


data = json.loads(results)

# Function to create nodes and relationships
def create_graph(tx, data):
    created_nodes = set()

    for item in data:
        node_1 = item['node_1']
        node_2 = item['node_2']
        edge = item['edge']
        print(item['node_1'])
        print(item['node_2'])
        if node_1 not in created_nodes:
            tx.run("MERGE (n1:Entity {name: $name})", name=node_1)
            created_nodes.add(node_1)

        if node_2 not in created_nodes:
            tx.run("MERGE (n2:Entity {name: $name})", name=node_2)
            created_nodes.add(node_2)

        query = """
            MATCH (n1:Entity {name: $node_1}), (n2:Entity {name: $node_2})
            MERGE (n1)-[:`%s`]->(n2)
        """ % edge
        tx.run(query, node_1=node_1, node_2=node_2)

with driver.session() as session:
    session.execute_write(create_graph, data)
# Out:
# James Bond series
# James Bond
# James Bond
# British Secret Service agent
# James Bond
# Ian Fleming
# Ian Fleming
# novels
# Ian Fleming
# short-story collections
# Fleming
# Bond novels
# Fleming
# Bond novelisations
# Fleming
# 1964
# eight other authors
# Bond novels
# eight other authors
# Bond novelisations
# Kingsley Amis
# Bond novels
# Kingsley Amis
# Bond novelisations
# Christopher Wood
# Bond novels
# Christopher Wood
# Bond novelisations
# John Gardner
# Bond novels
# John Gardner
# Bond novelisations
# Raymond Benson
# Bond novels
# Raymond Benson
# Bond novelisations
# Sebastian Faulks
# Bond novels
# Sebastian Faulks
# Bond novelisations
# Jeffery Deaver
# Bond novels
# Jeffery Deaver
# Bond novelisations
# William Boyd
# Bond novels
# William Boyd
# Bond novelisations
# Anthony Horowitz
# Bond novels
# Anthony Horowitz
# Bond novelisations
# The latest novel
# With a Mind to Kill
# With a Mind to Kill
# Anthony Horowitz
# With a Mind to Kill
# May 2022
# Charlie Higson
# young James Bond series
# Kate Westbrook
# Moneypenny diaries novels
# James Bond
# 007
# James Bond
# young James Bond series
# Moneypenny
# Moneypenny diaries novels
# Sean Connery
# No
# You Only Live Twice
# 1967
# Sean Connery
# You Only Live Twice
# George Lazenby
# On Her Majesty's Secret Service
# On Her Majesty's Secret Service
# 1969
# George Lazenby
# 007
# Diamonds Are Forever
# Sean Connery
# Diamonds Are Forever
# Eon-produced film
# Sean Connery
# role
# Roger Moore
# 007
# Roger Moore
# Live and Let Die
# Live and Let Die
# 1973
# Bond
# He
# He
# Bond
# He
# Timothy Dalton
# Timothy Dalton
# He
# Bond
# six times
# six times
# Bond
# He
# twelve years
# twelve years
# He
# Timothy Dalton
# two films
# two films
# Timothy Dalton
# Six-year hiatus
# Eon's productions
# Legal wrangle
# Eon's productions
# Pierce Brosnan
# Bond
# Pierce Brosnan
# GoldenEye
# Pierce Brosnan
# Bond films
# Bond films
# 2002
# Daniel Craig
# Casino Royale (2006)
# Casino Royale (2006)
# film series
# Daniel Craig
# film series
# film series
# 2006
# film series
# $7 billion
# film series
# fifth-highest-grossing

# %%
# !pip install langchain_mistralai mistralai
# Out:
# Requirement already satisfied: langchain_mistralai in c:\users\shashwat's pc\appdata\local\programs\python\python310\lib\site-packages (0.1.9)
# Requirement already satisfied: mistralai in c:\users\shashwat's pc\appdata\local\programs\python\python310\lib\site-packages (0.4.2)
# Requirement already satisfied: langchain-core<0.3,>=0.2.2 in c:\users\shashwat's pc\appdata\local\programs\python\python310\lib\site-packages (from langchain_mistralai) (0.2.9)
# Requirement already satisfied: httpx-sse<1,>=0.3.1 in c:\users\shashwat's pc\appdata\local\programs\python\python310\lib\site-packages (from langchain_mistralai) (0.4.0)
# Requirement already satisfied: tokenizers<1,>=0.15.1 in c:\users\shashwat's pc\appdata\local\programs\python\python310\lib\site-packages (from langchain_mistralai) (0.19.1)
# Requirement already satisfied: httpx<1,>=0.25.2 in c:\users\shashwat's pc\appdata\local\programs\python\python310\lib\site-packages (from langchain_mistralai) (0.27.0)
# Requirement already satisfied: orjson<3.11,>=3.9.10 in c:\users\shashwat's pc\appdata\local\programs\python\python310\lib\site-packages (from mistralai) (3.10.5)
# Requirement already satisfied: pydantic<3,>=2.5.2 in c:\users\shashwat's pc\appdata\local\programs\python\python310\lib\site-packages (from mistralai) (2.7.1)
# Requirement already satisfied: certifi in c:\users\shashwat's pc\appdata\local\programs\python\python310\lib\site-packages (from httpx<1,>=0.25.2->langchain_mistralai) (2024.2.2)
# Requirement already satisfied: anyio in c:\users\shashwat's pc\appdata\local\programs\python\python310\lib\site-packages (from httpx<1,>=0.25.2->langchain_mistralai) (4.4.0)
# Requirement already satisfied: sniffio in c:\users\shashwat's pc\appdata\local\programs\python\python310\lib\site-packages (from httpx<1,>=0.25.2->langchain_mistralai) (1.3.1)
# Requirement already satisfied: httpcore==1.* in c:\users\shashwat's pc\appdata\local\programs\python\python310\lib\site-packages (from httpx<1,>=0.25.2->langchain_mistralai) (1.0.5)
# Requirement already satisfied: idna in c:\users\shashwat's pc\appdata\local\programs\python\python310\lib\site-packages (from httpx<1,>=0.25.2->langchain_mistralai) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\shashwat's pc\appdata\local\programs\python\python310\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.2->langchain_mistralai) (0.14.0)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\shashwat's pc\appdata\local\programs\python\python310\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain_mistralai) (8.4.1)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\shashwat's pc\appdata\local\programs\python\python310\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain_mistralai) (24.0)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in c:\users\shashwat's pc\appdata\local\programs\python\python310\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain_mistralai) (0.1.81)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\shashwat's pc\appdata\local\programs\python\python310\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain_mistralai) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\shashwat's pc\appdata\local\programs\python\python310\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain_mistralai) (1.33)
# Requirement already satisfied: pydantic-core==2.18.2 in c:\users\shashwat's pc\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3,>=2.5.2->mistralai) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\shashwat's pc\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3,>=2.5.2->mistralai) (4.12.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\shashwat's pc\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3,>=2.5.2->mistralai) (0.7.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\shashwat's pc\appdata\local\programs\python\python310\lib\site-packages (from tokenizers<1,>=0.15.1->langchain_mistralai) (0.23.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\shashwat's pc\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15.1->langchain_mistralai) (2024.6.0)
# Requirement already satisfied: requests in c:\users\shashwat's pc\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15.1->langchain_mistralai) (2.32.2)
# Requirement already satisfied: filelock in c:\users\shashwat's pc\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15.1->langchain_mistralai) (3.15.1)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\shashwat's pc\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15.1->langchain_mistralai) (4.66.4)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\shashwat's pc\appdata\local\programs\python\python310\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.2.2->langchain_mistralai) (2.4)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\shashwat's pc\appdata\local\programs\python\python310\lib\site-packages (from anyio->httpx<1,>=0.25.2->langchain_mistralai) (1.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shashwat's pc\appdata\local\programs\python\python310\lib\site-packages (from requests->huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15.1->langchain_mistralai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shashwat's pc\appdata\local\programs\python\python310\lib\site-packages (from requests->huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15.1->langchain_mistralai) (2.2.1)
# Requirement already satisfied: colorama in c:\users\shashwat's pc\appdata\local\programs\python\python310\lib\site-packages (from tqdm>=4.42.1->huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15.1->langchain_mistralai) (0.4.6)
# [notice] A new release of pip available: 22.2.1 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# have removed my credentials

# %%
import os

# Setting the private credentials

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.prompts.prompt import PromptTemplate
from mistralai.client import MistralClient
from mistralai.models.chat_completion import ChatMessage
from typing import List
# importing necessary libraries

# %%
# Built this to query my already made database

# %%
from neo4j import GraphDatabase
def structured_data(list1:List)->str:
    class Neo4jConnection:
        def __init__(self, uri, user, password):
            self._driver = GraphDatabase.driver(uri, auth=(user, password))
    
        def close(self):
            self._driver.close()
    
        def get_connected_nodes_by_property(self, property_name, property_value):
            query = f"""
            MATCH (n {{{property_name}: $propertyValue}})-[r]->(m)
            RETURN n.{property_name} AS startNode, type(r) AS relationship, m.{property_name} AS endNode
            UNION
            MATCH (n)<-[r]-(m {{{property_name}: $propertyValue}})
            RETURN m.{property_name} AS startNode, type(r) AS relationship, n.{property_name} AS endNode
            """
            with self._driver.session() as session:
                result = session.run(query, propertyValue=property_value)
                return [record for record in result]
    
    
    
    neo4j_conn = Neo4jConnection(uri, user, password)
    s=""
    for j in list1:
     property_name = "name"
     property_value = j
     connected_nodes = neo4j_conn.get_connected_nodes_by_property(property_name, property_value)
     
    
    for record in connected_nodes:
        s=s+f" {record['startNode']}-> {record['relationship']} --> {record['endNode']} \n"
    
    print(s)
    return s
    
    # Close the connection
    neo4j_conn.close()

# %%
# convert string to List

# %%
import ast

def convert_string_to_list(input_string):
    try:
        result_list = ast.literal_eval(input_string)
        if isinstance(result_list, list):
            return result_list
        else:
            raise ValueError("Input is not a valid list")
    except (ValueError, SyntaxError) as e:
        print(f"Error converting string to list: {e}")
        return None

# %%
# extracting necessary entities from a user query

# %%
def run_mistral(user_message, model="mistral-medium-latest"):
    messages = [
        ChatMessage(role="user", content=user_message)
    ]
    chat_response = client.chat(
        model=model,
        messages=messages
    )
    return (chat_response.choices[0].message.content)
def ans(question):
 prompt=f"""You are extracting organization and person entities or any important word from the text.
             your reply should be like [A1, A2,A3..]
             for example: "who is Akshay and Raj talking to? is that guy John from apple?"
             you will reply with -> ['Akshay','Raj','John','apple']
             NOTHING ELSE , so all i want is a list and no explanation of any sort , You will omit any kind of explanation. 
            the text is here--> {question}"""
 return convert_string_to_list(run_mistral(prompt))

# %%
type(ans("I want to know when was James Bond created  and who is the author? "))
ans("I want to know when was James Bond created  and who is the author? ")
# Out:
# ['James Bond', 'author']

# %%
context=structured_data(['Bond','Daniel Craig'])
# Out:
#  Daniel Craig-> is --> sixth
#  Daniel Craig-> portrays --> Bond
#  Daniel Craig-> has --> fifth
#  Daniel Craig-> played_in --> Casino Royale (2006)
#  Daniel Craig-> appeared_in --> film series

# %%
p=ans("I want to know who wrote James Bond ")
print(p)
context=structured_data(p)
# Out:
# ['James Bond']
#  James Bond-> is_a --> British Secret Service agent
#  James Bond-> created_by --> Ian Fleming
#  James Bond-> featured_in --> young James Bond series
#  James Bond-> also_known_as --> 007
#  James Bond-> adapted_for --> television
#  James Bond-> adapted_for --> radio
#  James Bond-> adapted_for --> comic strip
#  James Bond-> adapted_for --> video games
#  James Bond-> adapted_for --> film

# %%
# providing a proper output based on my context

# %%
def final_ans(question:str,context:str):
 print(context)
 template = f"""Answer the question based only on the following context:
 {context}
 if suppose the context doesn't have the adequate answer for my question.
 you will say " No information found"
 you will only use the context provided and omit from providing any Note: to explain my question
 or explain why no answer is avalaible
 And compulsarily you will not answer anything extra , only from the context provided, if no context given
 " No information found"
 Question: {question}
 Use natural language and be concise.
 Answer:"""
 print(run_mistral(template))

# %%
final_ans("who is James bond? ",context)
# Out:
#  James Bond-> is_a --> British Secret Service agent
#  James Bond-> created_by --> Ian Fleming
#  James Bond-> featured_in --> young James Bond series
#  James Bond-> also_known_as --> 007
#  James Bond-> adapted_for --> television
#  James Bond-> adapted_for --> radio
#  James Bond-> adapted_for --> comic strip
#  James Bond-> adapted_for --> video games
#  James Bond-> adapted_for --> film
#
# James Bond is a British Secret Service agent, also known as 007. He was created by Ian Fleming and has been featured in the young James Bond series, as well as being adapted for television, radio, comic strips, video games, and film.

# %%
# calling all functions in one function

# %%
def final_final_ans(questions:str):
    entities=ans(questions)
    str_data=structured_data(entities)
    if str_data =='':
        str_data="No information found"
    final_ans(questions,str_data)

# %%
final_final_ans("who is iron man")
# Out:
# No information found
# No information found.

# %%
final_final_ans("what did  Fleming write?  ")
# Out:
#  Fleming-> wrote --> Bond novels
#  Fleming-> wrote --> Bond novelisations
#  Fleming-> died_in --> 1964
#
#  Fleming-> wrote --> Bond novels
#  Fleming-> wrote --> Bond novelisations
#  Fleming-> died_in --> 1964
#
# Fleming wrote Bond novels and Bond novelizations.

# %%
final_final_ans("What did Daniel Craig do?")
# Out:
#  Daniel Craig-> is --> sixth
#  Daniel Craig-> portrays --> Bond
#  Daniel Craig-> has --> fifth
#  Daniel Craig-> played_in --> Casino Royale (2006)
#  Daniel Craig-> appeared_in --> film series
#
#  Daniel Craig-> is --> sixth
#  Daniel Craig-> portrays --> Bond
#  Daniel Craig-> has --> fifth
#  Daniel Craig-> played_in --> Casino Royale (2006)
#  Daniel Craig-> appeared_in --> film series
#
# Daniel Craig portrays Bond, has played in five films, including Casino Royale (2006), and appeared in the film series. He is also the sixth in this role.

# %%
# fails to provide ans to detailed questions

# %%
final_final_ans("who wrote six Bond novels ?")
# Out:
#  Bond-> is_a --> 00 agent
#  Bond-> series --> Eon Productions
#  Bond-> played_by --> Daniel Craig
#  Bond-> is_part_of --> Eon series
#  Bond-> is_played_by --> actor
#  Bond-> published in --> Scorpius
#  Bond-> published in --> Win, Lose or Die
#  Bond-> published in --> Brokenclaw
#  Bond-> published in --> The Man from Barbarossa
#  Bond-> published in --> Death Is Forever
#  Bond-> published in --> Never Send Flowers
#  Bond-> published in --> SeaFire
#  Bond-> published in --> Cold
#  Bond-> novelisation of --> Licence to Kill
#  Bond-> novelisation of --> GoldenEye
#  Bond-> played --> He
#  Bond-> played --> six times
#
#  Bond-> is_a --> 00 agent
#  Bond-> series --> Eon Productions
#  Bond-> played_by --> Daniel Craig
#  Bond-> is_part_of --> Eon series
#  Bond-> is_played_by --> actor
#  Bond-> published in --> Scorpius
#  Bond-> published in --> Win, Lose or Die
#  Bond-> published in --> Brokenclaw
#  Bond-> published in --> The Man from Barbarossa
#  Bond-> published in --> Death Is Forever
#  Bond-> published in --> Never Send Flowers
#  Bond-> published in --> SeaFire
#  Bond-> published in --> Cold
#  Bond-> novelisation of --> Licence to Kill
#  Bond-> novelisation of --> GoldenEye
#  Bond-> played --> He
#  Bond-> played --> six times
#
# No information found.
#
# Confidence: 100%

# %%
final_final_ans("who is Raymond Benson?")
# Out:
#  Raymond Benson-> wrote --> Bond novels
#  Raymond Benson-> wrote --> Bond novelisations
#  Raymond Benson-> author of --> Bond novels
#
#  Raymond Benson-> wrote --> Bond novels
#  Raymond Benson-> wrote --> Bond novelisations
#  Raymond Benson-> author of --> Bond novels
#
# Raymond Benson is an author known for writing Bond novels and novelisations.
